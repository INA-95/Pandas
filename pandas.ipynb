# %% [markdown]
# <a href="https://colab.research.google.com/github/INA-95/Pandas/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Python/w3resource/diamonds.csv')
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# 1 Write a Pandas program to read a csv file from a specified source and print the first 5 rows.
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
# 2. Write a Pandas program to read a dataset from diamonds DataFrame and modify the default columns values and print the first 6 rows.
default_cols = ['carat', 'cut', 'color']
df[default_cols].head(6)
# Out:
#    carat        cut color
# 0   0.23      Ideal     E
# 1   0.21    Premium     E
# 2   0.23       Good     E
# 3   0.29    Premium     I
# 4   0.31       Good     J
# 5   0.24  Very Good     J

# %%
# 3. Write a Pandas program to select a series from diamonds DataFrame. Print the content of the series.
df['carat']
# Out:
# 0        0.23
# 1        0.21
# 2        0.23
# 3        0.29
# 4        0.31
#          ...
# 53935    0.72
# 53936    0.72
# 53937    0.70
# 53938    0.86
# 53939    0.75
# Name: carat, Length: 53940, dtype: float64

# %%
# 4. Write a Pandas program to create a new 'Quality -color' Series (use bracket notation to define the Series name) of the diamonds DataFrame.
df['Quality-color'] = df['cut'] + '-' + df['color']
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z Quality-color
# 0  2.43       Ideal-E
# 1  2.31     Premium-E
# 2  2.31        Good-E
# 3  2.63     Premium-I
# 4  2.75        Good-J

# %%
# 5. Write a Pandas program to find the number of rows and columns and data type of each column of diamonds Dataframe.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53940 non-null  int64
#  1   carat          53940 non-null  float64
#  2   cut            53940 non-null  object
#  3   color          53940 non-null  object
#  4   clarity        53940 non-null  object
#  5   depth          53940 non-null  float64
#  6   table          53940 non-null  float64
#  7   price          53940 non-null  int64
#  8   x              53940 non-null  float64
#  9   y              53940 non-null  float64
#  10  z              53940 non-null  float64
#  11  Quality-color  53940 non-null  object
# dtypes: float64(6), int64(2), object(4)
# memory usage: 4.9+ MB

# %%
# 6. Write a Pandas program to summarize only 'object' columns of the diamonds Dataframe.

df.describe(include=['object'])
# Out:
#           cut  color clarity Quality-color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1       Ideal-G
# freq    21551  11292   13065          4884

# %%
# 7. Write a Pandas program to rename two of the columns of the diamonds Dataframe.

df.rename(columns = {'cut' : 'quality'}, inplace = True)
df.rename(columns = {'Qulity-color' : 'quality-color'}, inplace = True)

# %%
# 7 at once

cols = {'x':'X', 'y':'Y', 'z':'Z'}
def rename_col_columns(df:pd.DataFrame, cols:dict):
    df.rename(columns=cols, inplace = True)
    return df.columns

# %%
# 8. Write a Pandas program to rename all the columns of the diamonds Dataframe.

new_cols = ['new_Unnamed: 0', 'new_carat', 'new_quality', 'new_color', 'new_clarity', 'new_depth', 'new_table', 'new_price', 'new_X', 'new_Y', 'new_Z', 'new_Quality-color']
df.columns = new_cols
df.head()
# Out:
#    new_Unnamed: 0  new_carat new_quality new_color new_clarity  new_depth  \
# 0               1       0.23       Ideal         E         SI2       61.5
# 1               2       0.21     Premium         E         SI1       59.8
# 2               3       0.23        Good         E         VS1       56.9
# 3               4       0.29     Premium         I         VS2       62.4
# 4               5       0.31        Good         J         SI2       63.3
#
#    new_table  new_price  new_X  new_Y  new_Z new_Quality-color
# 0       55.0        326   3.95   3.98   2.43           Ideal-E
# 1       61.0        326   3.89   3.84   2.31         Premium-E
# 2       65.0        327   4.05   4.07   2.31            Good-E
# 3       58.0        334   4.20   4.23   2.63         Premium-I
# 4       58.0        335   4.34   4.35   2.75            Good-J

# %%
# 9. Write a Pandas program to remove the second column of the diamonds Dataframe.

df.drop(columns=df.columns[1], inplace = True)
df.head()
# Out:
#    new_Unnamed: 0 new_quality new_color new_clarity  new_depth  new_table  \
# 0               1       Ideal         E         SI2       61.5       55.0
# 1               2     Premium         E         SI1       59.8       61.0
# 2               3        Good         E         VS1       56.9       65.0
# 3               4     Premium         I         VS2       62.4       58.0
# 4               5        Good         J         SI2       63.3       58.0
#
#    new_price  new_X  new_Y  new_Z new_Quality-color
# 0        326   3.95   3.98   2.43           Ideal-E
# 1        326   3.89   3.84   2.31         Premium-E
# 2        327   4.05   4.07   2.31            Good-E
# 3        334   4.20   4.23   2.63         Premium-I
# 4        335   4.34   4.35   2.75            Good-J

# %%
# 10. Write a Pandas program to remove multiple columns at once of the diamonds Dataframe.

remove_cols = ['new_quality', 'new_color']
df.drop(columns = remove_cols, inplace = True)
df.head()
# Out:
#    new_Unnamed: 0 new_clarity  new_depth  new_table  new_price  new_X  new_Y  \
# 0               1         SI2       61.5       55.0        326   3.95   3.98
# 1               2         SI1       59.8       61.0        326   3.89   3.84
# 2               3         VS1       56.9       65.0        327   4.05   4.07
# 3               4         VS2       62.4       58.0        334   4.20   4.23
# 4               5         SI2       63.3       58.0        335   4.34   4.35
#
#    new_Z new_Quality-color
# 0   2.43           Ideal-E
# 1   2.31         Premium-E
# 2   2.31            Good-E
# 3   2.63         Premium-I
# 4   2.75            Good-J

# %%
# 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to rows) from diamonds dataframe.

rows = [0, 1]
df.drop(rows, inplace = True)
df.head()
# Out:
#    new_Unnamed: 0 new_clarity  new_depth  new_table  new_price  new_X  new_Y  \
# 2               3         VS1       56.9       65.0        327   4.05   4.07
# 3               4         VS2       62.4       58.0        334   4.20   4.23
# 4               5         SI2       63.3       58.0        335   4.34   4.35
# 5               6        VVS2       62.8       57.0        336   3.94   3.96
# 6               7        VVS1       62.3       57.0        336   3.95   3.98
#
#    new_Z new_Quality-color
# 2   2.31            Good-E
# 3   2.63         Premium-I
# 4   2.75            Good-J
# 5   2.48       Very Good-J
# 6   2.47       Very Good-I

# %%
# 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a Series) of diamonds Dataframe.

df.sort_values(by = 'new_price', ascending = True)
# Out:
#        new_Unnamed: 0 new_clarity  new_depth  new_table  new_price  new_X  \
# 2                   3         VS1       56.9       65.0        327   4.05
# 3                   4         VS2       62.4       58.0        334   4.20
# 4                   5         SI2       63.3       58.0        335   4.34
# 5                   6        VVS2       62.8       57.0        336   3.94
# 6                   7        VVS1       62.3       57.0        336   3.95
# ...               ...         ...        ...        ...        ...    ...
# 27745           27746         SI1       62.8       57.0      18803   7.95
# 27746           27747         SI2       62.5       55.0      18804   8.20
# 27747           27748          IF       61.7       55.0      18806   7.37
# 27748           27749         SI1       63.5       56.0      18818   7.90
# 27749           27750         VS2       60.8       60.0      18823   8.50
#
#        new_Y  new_Z new_Quality-color
# 2       4.07   2.31            Good-E
# 3       4.23   2.63         Premium-I
# 4       4.35   2.75            Good-J
# 5       3.96   2.48       Very Good-J
# 6       3.98   2.47       Very Good-I
# ...      ...    ...               ...
# 27745   8.00   5.01       Very Good-H
# 27746   8.13   5.11           Ideal-G
# 27747   7.41   4.56           Ideal-G
# 27748   7.97   5.04       Very Good-G
# 27749   8.47   5.16         Premium-I
#
# [53938 rows x 9 columns]

# %%
# 13. Write a Pandas program to sort the 'price' Series in descending order (returns a Series) of diamonds Dataframe.

def sort_col_val(df:pd.DataFrame, col:str, order:str) -> pd.Series:
    if order == 'asc':
        df.sort_values(by = col, inplace = True)
    elif order == 'des':
        df.sort_values(by = col, ascending = False, inplace = True)
    return df[col]

# %%
sort_col_val(df, 'new_price', 'des')
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 6          336
# 5          336
# 4          335
# 3          334
# 2          327
# Name: new_price, Length: 53938, dtype: int64

# %%
# 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat' Series in ascending and descending order.

# %%
# 15. Write a Pandas program to filter the DataFrame rows to only show carat weight at least 0.3.

df[df['new_price'] > 336]

# %%
# 16. Write a Pandas program to convert a python list to pandas series.

res = []
lst = [res.append(v) for v in df['new_Quality-color'] if v not in res]

def convert_lst_to_series(lst:list) -> pd.Series:
    result = pd.Series(lst)
    return result

# %%
convert_lst_to_series(res)

# %%
# 17. Write a Pandas program to find the details of the diamonds where length>5, width>5 and depth>5.

df[(df['new_X'] > 4) & (df['new_Y'] > 4)]

# %%
# 18. Write a Pandas program to find the diamonds that are either Premium or Ideal.

df[df['new_Quality-color'].str.contains('Premium') | df['new_Quality-color'].str.contains('Ideal')].sample(10)
# Out:
#        new_Unnamed: 0 new_clarity  new_depth  new_table  new_price  new_X  \
# 47341           47342         VS2       62.3       55.0       1845   5.11
# 13003           13004         SI2       61.6       57.0       5405   6.56
# 49201           49202         VS2       61.2       56.0       2079   5.44
# 25489           25490         SI2       62.2       56.0      14277   8.34
# 34265           34266         SI1       60.9       60.0        465   4.38
# 31378           31379          IF       60.4       58.0        761   4.41
# 23617           23618         SI1       62.2       53.0      11642   7.38
# 10374           10375         SI1       62.2       58.0       4777   6.73
# 4170             4171         VS1       61.6       56.0       3554   5.80
# 45317           45318         VS1       61.6       59.0        524   4.37
#
#        new_Y  new_Z new_Quality-color
# 47341   5.07   3.17           Ideal-D
# 13003   6.53   4.03           Ideal-F
# 49201   5.45   3.33           Ideal-E
# 25489   8.29   5.18           Ideal-I
# 34265   4.36   2.66         Premium-J
# 31378   4.43   2.67         Premium-H
# 23617   7.31   4.57           Ideal-E
# 10374   6.77   4.20         Premium-I
# 4170    5.73   3.55           Ideal-D
# 45317   4.39   2.70         Premium-H

# %%
# 19. Write a Pandas program to find the diamonds that are with a Fair or Good or Premium.

df[df['new_Quality-color'].str.contains('Good') | df['new_Quality-color'].str.contains('Premium') | df['new_Quality-color'].str.contains('Fair')].sample(10)
# Out:
#        new_Unnamed: 0 new_clarity  new_depth  new_table  new_price  new_X  \
# 33817           33818        VVS1       63.9       56.0        842   4.64
# 43351           43352         VS2       63.3       56.0       1407   5.11
# 9663             9664         VS2       63.0       57.0       4643   6.07
# 8872             8873         SI2       59.2       58.0       4484   6.64
# 25137           25138         VS2       57.0       66.0      13701   8.80
# 6271             6272        VVS2       61.7       58.0       4014   5.71
# 8851             8852         SI1       64.8       58.0       4480   6.34
# 47268           47269        VVS1       60.9       58.0       1844   5.74
# 18029           18030        VVS2       62.3       60.0       7292   6.38
# 25218           25219         VS2       62.0       59.0      13819   7.18
#
#        new_Y  new_Z new_Quality-color
# 33817   4.68   2.98            Good-I
# 43351   5.03   3.21            Good-E
# 9663    6.15   3.85       Very Good-E
# 8872    6.70   3.95         Premium-E
# 25137   8.60   4.98            Fair-J
# 6271    5.74   3.53       Very Good-D
# 8851    6.29   4.09            Fair-E
# 47268   5.79   3.51         Premium-J
# 18029   6.49   4.01            Good-G
# 25218   7.37   4.51            Good-F

# %%
# 20. Write a Pandas program to display all column labels of diamonds DataFrame.

df.columns
# Out:
# Index(['new_Unnamed: 0', 'new_clarity', 'new_depth', 'new_table', 'new_price',
#        'new_X', 'new_Y', 'new_Z', 'new_Quality-color'],
#       dtype='object')
